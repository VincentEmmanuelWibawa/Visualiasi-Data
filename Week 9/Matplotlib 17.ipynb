# %% [markdown]
# # Import modules

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style
print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.8.4
# 1.26.4

# %% [markdown]
# # Predefined Styles

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
x = np.linspace(1, 10, 15)

plt.plot(x, x, 'bs-', label='lin')
plt.plot(x, np.log(x), 'ro-', label='log')

plt.legend()
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Plot')

plt.show()

# %% [markdown]
# # Membuat Style sendiri

# %%
plt.style.use(r"C:\Users\Asus\OneDrive\Desktop\style_ku.txt")
# Out:
# Missing colon in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 1 ('{')
# Missing colon in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 3 ('  {')
# Missing colon in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 16 ('   ]')
# Missing colon in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 17 ('  }')
# Missing colon in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 18 (' ],')
# Duplicate key in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 19 (' "metadata": {')
# Missing colon in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 24 ('  },')
# Duplicate key in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 27 ('    "name": "ipython",')
# Missing colon in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 29 ('   },')
# Duplicate key in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 32 ('   "name": "python",')
# Duplicate key in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 35 ('   "version": "3.12.4"')
# Missing colon in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 36 ('  }')
# Missing colon in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 37 (' },')
# Missing colon in file 'C:\\Users\\Asus\\OneDrive\\Desktop\\CobaStyle.ipynb', line 40 ('}')
#
# Bad key "cells" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 2 (' "cells": [')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "cell_type" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 4 ('   "cell_type": "code",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "execution_count" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 5 ('   "execution_count": null,')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "id" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 6 ('   "id": "d86fa9a5-a12c-44e0-adce-198eacb7a7d3",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "metadata" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 19 (' "metadata": {')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "outputs" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 8 ('   "outputs": [],')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "source" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 9 ('   "source": [')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "axes.titlesize in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 10 ('    "axes.titlesize : 24\\n",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "axes.labelsize in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 11 ('    "axes.labelsize : 20 \\n",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "lines.linewidth in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 12 ('    "lines.linewidth : 3\\n",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "lines.markersize in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 13 ('    "lines.markersize : 10\\n",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "xtick.labelsize in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 14 ('    "xtick.labelsize : 16\\n",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "ytick.labelsize in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 15 ('    "ytick.labelsize : 16"')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "kernelspec" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 20 ('  "kernelspec": {')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "display_name" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 21 ('   "display_name": "Python 3 (ipykernel)",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "language" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 22 ('   "language": "python",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "name" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 32 ('   "name": "python",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "language_info" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 25 ('  "language_info": {')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "codemirror_mode" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 26 ('   "codemirror_mode": {')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "version" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 35 ('   "version": "3.12.4"')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "file_extension" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 30 ('   "file_extension": ".py",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "mimetype" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 31 ('   "mimetype": "text/x-python",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "nbconvert_exporter" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 33 ('   "nbconvert_exporter": "python",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "pygments_lexer" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 34 ('   "pygments_lexer": "ipython3",')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "nbformat" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 38 (' "nbformat": 4,')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key "nbformat_minor" in file C:\Users\Asus\OneDrive\Desktop\CobaStyle.ipynb, line 39 (' "nbformat_minor": 5')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.4/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution

# %%
x = np.linspace(1, 10, 15)

plt.plot(x, x, 'bs-', label='lin')
plt.plot(x, np.log(x), 'ro-', label='log')

plt.legend()
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Plot')

plt.show()

# %% [markdown]
# # Menerapkan multiple style

# %%
plt.style.use([ 'seaborn-v0_8', 'dark_background'])

# %%
x = np.linspace(1, 10, 15)

plt.plot(x, x, 'bs-', label='lin')
plt.plot(x, np.log(x), 'ro-', label='log')

plt.legend()
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Plot')

plt.show()

# %% [markdown]
# # Menerapkan temporary styling

# %%
plt.style.use('ggplot')

plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.show()

# %%
with plt.style.context('dark_background'):
    plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')

plt.show()

# %%
plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.show()
